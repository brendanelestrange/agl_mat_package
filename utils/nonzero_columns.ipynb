# %%
import pandas as pd

# %%
df = pd.read_csv("../Features/tmQMg_properties_and_targets_AGL_TM_CPP_k1000_c10.0.csv")

non_zero_cols = df.columns[df.any()]

# %%
data_cols = df.drop(columns=['ID', 'Target'])
active_features = data_cols.columns[(data_cols != 0).any()]

print(f"Total columns: {len(df.columns)}")
print(f"Non-zero columns: {len(active_features)}")
print(active_features.tolist())
# Out:
# Total columns: 4002
# Non-zero columns: 2268
# ...
